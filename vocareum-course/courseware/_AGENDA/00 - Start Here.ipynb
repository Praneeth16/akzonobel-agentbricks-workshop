# %% [markdown]
# # AkzoNobel Agent Bricks Workshop — Start Here
#
# Welcome. This is your landing notebook. It maps the workshop and tells you what to run first.
#
# > All data is synthetic. Product names, customers, suppliers, and documents are invented for the workshop.
#
# ---
#
# ## What you will build
#
# | Capability | Powered by |
# |---|---|
# | AI from pure SQL (classify, extract, parse, summarize, mask, forecast) | SQL AI Functions |
# | Natural-language data queries | Genie Space |
# | Document Q&A over safety sheets and policies | Knowledge Assistant |
# | Field extraction and PDF parsing | Information Extraction, Document Parsing |
# | Ticket and email triage | Text Classification |
# | Agent quality evaluation | MLflow Tracing + LLM judge |
# | Short-term memory | Lakebase |
#
# ---
#
# ## Run order
#
# 1. **`01 - Setup Check`** — run this first. It confirms your catalog and that the shared data is loaded.
# 2. **L100 notebooks** (SQL AI Functions, Agent Bricks Types, Agent Evaluation, Short-Term Memory).
# 3. **L200 / L300** — added as the workshop grows.
# 4. **`90 - Optional Advanced`** — fork a hackathon track.
# 5. **`99 - Wrap Up`** — recap and next steps.
#
# ---
#
# ## Before you run anything
#
# Every notebook is portable: the **catalog** widget defaults to your assigned lab catalog (`current_catalog()`), so nothing is tied to one workspace. If your data lives elsewhere, set the `catalog` widget at the top of each notebook.
#
# Go to **`01 - Setup Check`** now.
