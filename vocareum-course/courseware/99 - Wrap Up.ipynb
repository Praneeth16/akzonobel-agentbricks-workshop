# %% [markdown]
# # 99 - Wrap Up
#
# Nice work. Here is what you built and where to go next.
#
# ## What you built
#
# - Called AI from pure SQL: classify, extract, parse, summarize, mask, forecast.
# - Created the no-code Agent Bricks types: Genie, Knowledge Assistant, Information Extraction, Document Parsing, Text Classification.
# - Evaluated an agent with MLflow and an LLM judge.
# - Gave an agent short-term memory on Lakebase.
#
# ## Where to go next
#
# - **L200 — Capabilities:** build and register your own MCP server, add tools, and ship an agent that acts behind a human approval gate.
# - **L300 — Multi-domain Supervisor:** the flagship that routes across Finance, SCM, and Commercial Genie spaces.
# - **Hackathon Starter Kit:** fork a track (`90 - Optional Advanced`) and build a copilot for a real AkzoNobel use case.
#
# ## Before you end the lab
#
# - Save anything you want to keep.
# - Lab resources are removed when the session ends — do not click **End Lab** until you are done.
#
# > All data was synthetic. Thanks for joining the workshop.
